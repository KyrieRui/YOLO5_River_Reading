# %%
from roboflow import Roboflow
rf = Roboflow(api_key="R67H2N2zC2c2qrXttbVb")
project = rf.workspace("boprc").project("water-level-measurement")
dataset = project.version(1).download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Water-Level-Measurement-1 in yolov5pytorch:: 100%|██████████| 32/32 [00:00<00:00, 5016.36it/s]

# %%
tensorboard --logdir=runs
# Out:
#   Cell In[1], line 1
#     tensorboard --logdir=runs
#     ^
# SyntaxError: cannot assign to operator

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="R67H2N2zC2c2qrXttbVb")
project = rf.workspace("abdi-fatah-fauzan-yryp6").project("datas2")
dataset = project.version(4).download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to DATAS2-4 in yolov5pytorch:: 100%|██████████| 1482/1482 [00:00<00:00, 6066.05it/s]

# %%
# !python export.py --include tflite --imgsz 640 --weights yolov5s.pt
# Out:
# export: data=data/coco128.yaml, weights=['yolov5s.pt'], imgsz=[640], batch_size=1, device=cpu, half=False, inplace=False, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=17, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['tflite']
# YOLOv5 🚀 v7.0-247-g3f02fde Python-3.9.18 torch-2.0.1 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
#
# PyTorch: starting from yolov5s.pt with output shape (1, 25200, 85) (14.1 MB)
# TensorFlow SavedModel: export failure ❌ 0.0s: dlopen(/Users/zwang/myenv/lib/python3.9/site-packages/tensorflow/python/platform/_pywrap_cpu_feature_guard.so, 0x0002): Library not loaded: '@rpath/libtensorflow_cc.2.dylib'
#   Referenced from: '/Users/zwang/myenv/lib/python3.9/site-packages/tensorflow/python/_pywrap_tensorflow_internal.so'
# ...

# %%
# !python train.py --img 640 --batch 16 --epochs 10 --data DATAS2-4/data.yaml --weights yolov5s.pt
# Out:
# train: weights=yolov5s.pt, cfg=, data=DATAS2-4/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=10, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 2 commits. Use 'git pull' or 'git clone https://github.com/ultralytics/yolov5' to update.
# YOLOv5 🚀 v7.0-247-g3f02fde Python-3.9.18 torch-2.0.1 CPU
#
# ...

# %%
# !python detect.py --source DATAS2-4/valid/images --weights runs/train/exp4/weights/best.pt
# Out:
# detect: weights=['runs/train/exp4/weights/best.pt'], source=DATAS2-4/valid/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-247-g3f02fde Python-3.9.18 torch-2.0.1 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7037095 parameters, 0 gradients, 15.8 GFLOPs
# image 1/73 /Users/zwang/Desktop/YOLOV5/yolov5/DATAS2-4/valid/images/IMG_20230704_102114_jpg.rf.2aee744027ce21be31baa723f93228c4.jpg: 640x640 2 90s, 2 staffs, 129.3ms
# image 2/73 /Users/zwang/Desktop/YOLOV5/yolov5/DATAS2-4/valid/images/IMG_20230704_102238_jpg.rf.abfaa41171ecfd72254309f41e279463.jpg: 640x640 1 staff, 137.3ms
# ...

# %%
# !python detect.py --source BOPRC_test --weights runs/train/exp/weights/best.pt
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=BOPRC_test, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-247-g3f02fde Python-3.9.18 torch-2.0.1 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7037095 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /Users/zwang/Desktop/YOLOV5/yolov5/BOPRC_test/MicrosoftTeams-image (1).png: 512x640 1 staff, 106.2ms
# Speed: 0.6ms pre-process, 106.2ms inference, 0.8ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp2

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="R67H2N2zC2c2qrXttbVb")
project = rf.workspace("bali-tower").project("water-ruler")
dataset = project.version(4).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.0.227, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to water-ruler-4 in yolov8:: 100%|██████████| 1044/1044 [00:00<00:00, 6546.85it/s]

# %%
# !python train.py --img 640 --batch 16 --epochs 1 --data water-ruler-4/data.yaml --weights yolov5s.pt
# Out:
# train: weights=yolov5s.pt, cfg=, data=water-ruler-4/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=1, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 2 commits. Use 'git pull' or 'git clone https://github.com/ultralytics/yolov5' to update.
# YOLOv5 🚀 v7.0-247-g3f02fde Python-3.9.18 torch-2.0.1 CPU
#
# ...

# %%
# !python detect.py --source BOPRC_test --weights runs/train/exp/weights/best.pt
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=BOPRC_test, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-247-g3f02fde Python-3.9.18 torch-2.0.1 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7037095 parameters, 0 gradients, 15.8 GFLOPs
# image 1/33 /Users/zwang/Desktop/YOLOV5/yolov5/BOPRC_test/1.jpg: 640x480 1 staff, 88.8ms
# image 2/33 /Users/zwang/Desktop/YOLOV5/yolov5/BOPRC_test/10.jpg: 640x480 (no detections), 90.8ms
# image 3/33 /Users/zwang/Desktop/YOLOV5/yolov5/BOPRC_test/11.jpg: 640x480 (no detections), 89.7ms
# ...

# %%
# !python detect.py --source BOPRC_test --weights runs/train/exp/weights/best.pt

# %%
# !python detect.py --source 0 --weights runs/train/exp/weights/best.pt --img-size 1920
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=0, data=data/coco128.yaml, imgsz=[1920, 1920], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 492b9fd Python-3.11.7 torch-2.1.2 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7037095 parameters, 0 gradients, 15.8 GFLOPs
# 1/1: 0...  Success (inf frames 1280x720 at 30.00 FPS)
#
# 0: 1088x1920 (no detections), 524.3ms
# 0: 1088x1920 (no detections), 496.6ms
# 0: 1088x1920 (no detections), 463.5ms
# 0: 1088x1920 (no detections), 458.8ms
# 0: 1088x1920 (no detections), 460.6ms
# 0: 1088x1920 (no detections), 464.1ms
# 0: 1088x1920 (no detections), 468.6ms
# 0: 1088x1920 (no detections), 468.1ms
# ...

# %%
# !python detect.py --source 0 --weights runs/train/exp/weights/best.pt
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=0, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 492b9fd Python-3.11.7 torch-2.1.2 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7037095 parameters, 0 gradients, 15.8 GFLOPs
# 1/1: 0...  Success (inf frames 1280x720 at 30.00 FPS)
#
# 0: 384x640 (no detections), 89.7ms
# 0: 384x640 (no detections), 70.8ms
# 0: 384x640 (no detections), 68.9ms
# 0: 384x640 (no detections), 65.4ms
# 0: 384x640 (no detections), 66.2ms
# 0: 384x640 (no detections), 69.0ms
# 0: 384x640 (no detections), 67.6ms
# 0: 384x640 (no detections), 69.8ms
# ...

# %%
# !python detect.py --source 0
# Out:
# detect: weights=yolov5s.pt, source=0, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 d24ae66 Python-3.11.7 torch-2.1.2 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# 1/1: 0...  Success (inf frames 1280x720 at 30.00 FPS)
#
# 0: 384x640 1 person, 1 tie, 74.9ms
# 0: 384x640 1 person, 1 tie, 67.8ms
# 0: 384x640 1 person, 70.9ms
# 0: 384x640 1 person, 68.9ms
# 0: 384x640 1 person, 65.7ms
# 0: 384x640 1 person, 65.8ms
# 0: 384x640 1 person, 1 tie, 66.0ms
# 0: 384x640 1 person, 63.4ms
# 0: 384x640 1 person, 63.2ms
# 0: 384x640 1 person, 66.9ms
# ...

# %%
# !python export.py --include tflite --imgsz 640 --weights yolov5s.pt

# %%
# !conda activate yolov5

# %%
# !python export.py --weights runs/train/exp/weights/best.pt --include tflite
# Out:
# /Users/zwang/Documents/GitHub/YOLO5_River_Reading/export.py:59: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# export: data=data/coco128.yaml, weights=['runs/train/exp/weights/best.pt'], imgsz=[640, 640], batch_size=1, device=cpu, half=False, inplace=False, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=17, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['tflite']
# YOLOv5 🚀 492b9fd Python-3.11.7 torch-2.1.2 CPU
#
# Fusing layers...
# ...

# %%
import tensorflow.lite as tflite

# Load the TFLite model
interpreter = tflite.Interpreter(model_path="runs/train/exp/weights/best-fp16.tflite")
interpreter.allocate_tensors()

# Get the input and output details
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# Print the output details, including the shape
print("Output shape:", output_details[0]['shape'])
# Out:
# Output shape: [    1 25200    15]
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.

# %%
# !python export.py --include tflite --imgsz 320 --weights runs/train/exp/weights/best.pt
# Out:
# /Users/zwang/Documents/GitHub/YOLO5_River_Reading/export.py:59: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# export: data=data/coco128.yaml, weights=['runs/train/exp/weights/best.pt'], imgsz=[320], batch_size=1, device=cpu, half=False, inplace=False, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=17, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['tflite']
# YOLOv5 🚀 492b9fd Python-3.11.7 torch-2.1.2 CPU
#
# Fusing layers...
# ...
